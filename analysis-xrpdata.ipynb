# %%
import pandas as pd

# %%
data = pd.read_json("xrpdata.json")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tx_hash  1250 non-null   object
#  1   from     1250 non-null   object
#  2   to       1250 non-null   object
#  3   amount   1250 non-null   object
# dtypes: object(4)
# memory usage: 39.2+ KB

# %%
data.head(20)
# Out:
#                                               tx_hash  \
# 0   0D893CE3354845ACF21E4DEC1AB0C2386EFA92F8B1A376...
# 1   1959FEB53C49D164F94EBC0CF5024E6277BA6E87E47FAB...
# 2   B7CE9C46520AD339EA29A1898D1B6D6E1839947F4A02A4...
# 3   4C673657DA14FCFE6C8A72DA36BC6D8DFC8CDC74B7908A...
# 4   A3AABF385DFE7EB13D179CF7272C20040770CF254838D7...
# 5   7B7F0246E32CC95BEE1D1DECE4DE553E933EE45B636361...
# 6   0FDA36D4FF989A82E895CEB7E37CF77862359A28ABD5D5...
# 7   9A9FF44DE2AB734AA339C44CEC6D5AFEF98D4BEE38AC8B...
# 8   FC87164268321725DF9A665751F6AC3F4D669D27FECDDB...
# 9   85071F6092E865F4EF0DE3016F8C034E3ECA121C77811E...
# 10  F5EE813540DEECDA1FBCE2B68B6FF7E65FAE39446213E6...
# 11  1C42D56113445C8E7FB640387D6DCC934B03BD0BD45BB3...
# 12  C563568CC3AAE4A639C9D32469C8CE95345B5EB1504DDD...
# 13  78D2686339B9FA5EAC034083742747DC72735C1F2C17F4...
# 14  15E1870399E551820B4B51F3040D637EA61CD85FE69A4E...
# 15  A27D6B0B329452AF021EA9ABD51AF9F2B0B40C855C121A...
# ...

# %%
# Transaction perform
# others to thodex, or thodex to other
# for exp: XRP transactions have been made 260 times from Thodex to rMo9M4e9spKDUMKos1ikt8pwyHi8K2j5tE
data.groupby(data.to).size()
# Out:
# to
# 1xBet                                   2
# BC.Game                                 1
# Binance                               517
# Bitay                                   1
# Bitexen                                19
# Bitfinex                                4
# Bitlo                                   3
# Bitpanda                                1
# Bittrex                                 1
# BtcTurk                                 1
# Bybit                                   1
# CoinPayments                            5
# FTX                                    26
# Gate                                    7
# HitBTC                                  2
# Kraken                                  1
# KuCoin                                  3
# MXC                                     2
# OKEx                                   11
# Paribu                                246
# Poloniex                                2
# Stake                                   2
# ...

# %%
data.groupby(data.from_).size()
# Out:
# from_
# 1xBet                                    1
# Binance                                 61
# Bitexen                                  3
# Bitfinex                                 2
# Bithumb                                  1
# Bitstamp                                 3
# CoinPayments                             1
# Dropz                                    3
# Gate                                     2
# Kraken                                   2
# KuCoin                                   2
# MXC                                      1
# NiceHash                                 3
# Paribu                                  10
# PayBis                                   1
# Stake                                    1
# Thodex                                1138
# Uphold                                   1
# r4igCGLFKHKJjB5TXJuwiqL52EHrREFCDk       1
# rMo9M4e9spKDUMKos1ikt8pwyHi8K2j5tE      10
# rPisS2Wd3QZztu7cjqiuTSEVSh2whMU3rZ       1
# rfh2ZmF3rUp27EPGWhbB53pPznAHGkYw8V       1
# ...
